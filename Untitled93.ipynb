# %% [markdown]
# <a href="https://colab.research.google.com/github/Zainakhader/project2/blob/main/Untitled93.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

pd.set_option('display.max_columns',200)
pd.set_option("display.max_info_rows", 800)
pd.set_option('display.max_info_columns',800)

from sklearn import set_config
set_config(transform_output='pandas')
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# Get Data
df = pd.read_csv('/content/flight_df - flight_df (1).csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   Age                                int64
#  1   Class                              int64
#  2   Flight Distance                    int64
#  3   Inflight wifi service              int64
#  4   Departure/Arrival time convenient  int64
#  5   Ease of Online booking             int64
#  6   Gate location                      int64
#  7   Food and drink                     int64
#  8   Online boarding                    int64
#  9   Seat comfort                       int64
#  10  Inflight entertainment             int64
#  11  On-board service                   int64
#  12  Leg room service                   int64
#  13  Baggage handling                   int64
#  14  Checkin service                    int64
#  15  Inflight service                   int64
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 Age         Class  Flight Distance  Inflight wifi service  \
# count  20000.000000  20000.000000     20000.000000           20000.000000
# mean      39.477250      2.027800      1188.548000               2.727950
# std       15.108901      0.963054      1001.136957               1.326886
# min        7.000000      1.000000        31.000000               0.000000
# 25%       27.000000      1.000000       414.000000               2.000000
# 50%       40.000000      2.000000       842.000000               3.000000
# 75%       51.000000      3.000000      1733.000000               4.000000
# max       85.000000      3.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       20000.000000            20000.000000
# mean                            3.056100                2.751100
# std                             1.531134                1.396799
# ...

# %%
# Scale the data
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
X_scaled.head()
# Out:
#         Age     Class  Flight Distance  Inflight wifi service  \
# 0 -0.892030  1.009522         0.872482              -0.548629
# 1  0.828853  1.009522        -0.507983               1.712360
# 2 -0.759654 -1.067256        -0.999437               0.205034
# 3  0.961229  1.009522        -0.734731               0.205034
# 4  0.034600 -1.067256        -0.413089               0.958697
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                          -0.036640                0.178198       0.022391
# 1                           1.269614                1.610079       1.585449
# 2                           1.269614                0.178198       0.803920
# 3                           1.269614                1.610079       1.585449
# 4                          -0.036640                0.178198       0.022391
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# ...

# %%
print('Number of Duplicated Rows', df.duplicated().sum())
print('\n')
# Out:
# Number of Duplicated Rows 0

# %%
# Iterate over a range of k clusters to find the optimal number of clusters
ks = range(2,11)
sils = []
inertias = []
for k in ks:
  kmeans = KMeans(n_clusters=k, n_init = 'auto', random_state=42)
  kmeans.fit(X_scaled)
  sils.append(silhouette_score(X_scaled, kmeans.labels_))
  inertias.append(kmeans.inertia_)
#plot inertias and silhouette scores for each number of clusters.
fig, axes = plt.subplots(1,2, figsize=(15,5))
axes[0].plot(ks, sils)
axes[0].set_title('Silhouette Scores')
axes[0].set_xticks(ks)
axes[1].plot(ks, inertias)
axes[1].set_title('Inertia')
axes[1].set_xticks(ks);

# %%
# Refit KMeans with 2 clusters
kmeans = KMeans(n_clusters=2, n_init= 'auto', random_state=42)
kmeans.fit(X_scaled)
# Add the clusters as a column in the dataframe
df['cluster'] = kmeans.labels_
df.head()
# Out:
#    Age  Class  Flight Distance  Inflight wifi service  \
# 0   26      3             2062                      2
# 1   52      3              680                      5
# 2   28      1              188                      3
# 3   54      3              453                      3
# 4   40      1              775                      4
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  3                       3              3
# 1                                  5                       5              5
# 2                                  5                       3              4
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0               2                2             2                       2
# ...

# %%
# Group the dataframe by cluster and aggregate by mean values
# Add as_index=False so that the clusters are a column, not the index
cluster_groups = df.groupby('cluster', as_index=False).mean()
cluster_groups
# Out:
#    cluster        Age     Class  Flight Distance  Inflight wifi service  \
# 0        0  37.201614  1.599248       908.592739               2.302558
# 1        1  42.206862  2.541845      1524.352689               3.238205
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                           3.013661                2.452462       2.936830
# 1                           3.107005                3.109315       3.012757
#
#    Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# 0        2.721097         2.576419      2.808288                2.600532
# 1        3.779061         4.069614      4.195755                4.247003
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0          2.889704          2.910149          3.231686          2.97607
# 1          3.979875          3.879468          4.093808          3.69482
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
# Visualize means
fig, axes = plt.subplots(3,4, figsize = (20, 10))
# fig is an array of dimensions 3,4.  axes.ravel() will flatten it to 12,1
axes = axes.ravel()
# Loop over columns and plot each in a separate figure, skip 'cluster' column
for i, col in enumerate(cluster_groups.columns[1:]):
    if i < len(axes):
        axes[i].bar(cluster_groups['cluster'], cluster_groups[col])
        axes[i].set_title(f'Mean {col}')
    else:
        break

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn import set_config
set_config(transform_output='pandas')

# %%
# Load data from your path
df = pd.read_csv("/content/flight_df - flight_df (1).csv", index_col=0)
df.head()
# Out:
#      Class  Flight Distance  Inflight wifi service  \
# Age
# 26       3             2062                      2
# 52       3              680                      5
# 28       1              188                      3
# 54       3              453                      3
# 40       1              775                      4
#
#      Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# Age
# 26                                   3                       3              3
# 52                                   5                       5              5
# 28                                   5                       3              4
# 54                                   5                       5              5
# 40                                   3                       3              3
#
#      Food and drink  Online boarding  Seat comfort  Inflight entertainment  \
# Age
# 26                2                2             2                       2
# ...

# %%
# Define X and y
target = 'satisfied'
X = df.drop(columns = target)
y = df[target]
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Check class balance
y_train.value_counts(normalize = True)
# Out:
# satisfied
# 0    0.565467
# 1    0.434533
# Name: proportion, dtype: float64

# %%
# Scale data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_tf = scaler.transform(X_train)
X_test_tf = scaler.transform(X_test)

# %%
# Step 1: Define our network structure
# Save the number of features we have as our input shape
input_shape = X_train_tf.shape[1]
input_shape
# Out:
# 21

# %%
# Sequential model
model = Sequential()

# %%
pca = PCA(n_components=0.95)  # Retain 95% variance
X_train_pca = pca.fit_transform(X_train_tf)
X_test_pca = pca.transform(X_test_tf)

# %%
print("Original number of features:", X_train_tf.shape[1])
print("Number of features after PCA:", X_train_pca.shape[1])
# Out:
# Original number of features: 21
# Number of features after PCA: 16

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn import set_config
set_config(transform_output='pandas')
